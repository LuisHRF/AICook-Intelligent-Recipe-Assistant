# %%
import pandas as pd

# %%
recipes_path = "data/processed/recipes_with_embeddings.parquet"
recipes_emb_path = "data/processed/recipes_embedded.parquet"
review_path = "data/raw/reviews.parquet"
recipes_raw = pd.read_parquet(recipes_path)
review_raw = pd.read_parquet(review_path)

# %%
recipes_raw.head(10)
# Out:
#    RecipeId                                        Name  \
# 0      38.0           Low-Fat Berry Blue Frozen Dessert
# 1      39.0                                     Biryani
# 2      40.0                               Best Lemonade
# 3      41.0              Carina's Tofu-Vegetable Kebabs
# 4      42.0                                Cabbage Soup
# 5      43.0                        Best Blackbottom Pie
# 6      44.0                      Warm Chicken A La King
# 7      45.0  Buttermilk Pie With Gingersnap Crumb Crust
# 8      46.0                     A Jad - Cucumber Pickle
# 9      47.0                        Butter Pecan Cookies
#
#                                  ingredients_cleaned  \
# 0  [blueberries, granulated sugar, vanilla yogurt...
# 1  [saffron, milk, hot green chili peppers, onion...
# 2  [sugar, lemons, rind of, lemon, zest of, fresh...
# 3  [extra firm tofu, eggplant, zucchini, mushroom...
# 4  [plain tomato juice, cabbage, onion, carrots, ...
# ...

# %%
embedded_or = pd.read_parquet(recipes_emb_path)

embedded_or.head(10)
# Out:
#    RecipeId                                        Name  \
# 0      38.0           Low-Fat Berry Blue Frozen Dessert
# 1      39.0                                     Biryani
# 2      40.0                               Best Lemonade
# 3      41.0              Carina's Tofu-Vegetable Kebabs
# 4      42.0                                Cabbage Soup
# 5      43.0                        Best Blackbottom Pie
# 6      44.0                      Warm Chicken A La King
# 7      45.0  Buttermilk Pie With Gingersnap Crumb Crust
# 8      46.0                     A Jad - Cucumber Pickle
# 9      47.0                        Butter Pecan Cookies
#
#                                ingredient_embeddings
# 0  [0.008872336, -0.055319756, 0.04511655, 0.0098...
# 1  [-0.04222925, -0.025312187, -0.014293986, 0.08...
# 2  [-0.039077178, -0.0002775647, -0.008472694, 0....
# 3  [-0.02865519, -0.034526974, -0.0081252605, 0.0...
# 4  [-0.002401564, 0.0307696, -0.029768908, 0.0425...
# ...

# %%
recipes_sample.head(5)
# Out:
#    RecipeId                               Name  AuthorId      AuthorName  \
# 0      38.0  Low-Fat Berry Blue Frozen Dessert      1533          Dancer
# 1      39.0                            Biryani      1567        elly9812
# 2      40.0                      Best Lemonade      1566  Stephen Little
# 3      41.0     Carina's Tofu-Vegetable Kebabs      1586         Cyclopz
# 4      42.0                       Cabbage Soup      1538       Duckie067
#
#   CookTime PrepTime TotalTime             DatePublished  \
# 0    PT24H    PT45M  PT24H45M 1999-08-09 21:46:00+00:00
# 1    PT25M     PT4H   PT4H25M 1999-08-29 13:12:00+00:00
# 2     PT5M    PT30M     PT35M 1999-09-05 19:52:00+00:00
# 3    PT20M    PT24H  PT24H20M 1999-09-03 14:54:00+00:00
# 4    PT30M    PT20M     PT50M 1999-09-19 06:19:00+00:00
#
#                                          Description  \
# 0  Make and share this Low-Fat Berry Blue Frozen ...
# 1  Make and share this Biryani recipe from Food.com.
# ...

# %%
non_string_elements = recipes_raw[recipes_raw['ingredients_cleaned'].apply(lambda lst: any(not isinstance(item, str) for item in lst))]
print(f"Number of lists with non-string elements: {len(non_string_elements)}")
# Out:
# Number of lists with non-string elements: 0

# %%
review_raw.shape
# Out:
# (1401982, 8)

# %%
import pandas as pd
import numpy as np

def data_summary(df): # Function for before all and check the raw dataframes

    # Check rows and colums
    shape = df.shape
    print("Number of columns ->", shape[1])
    print("Number of rows ->", shape[0])

    # Check duplicates rows
    #check_duplicates = df.duplicated().sum()
   # print("Number of duplicates ->", check_duplicates)

    # Create a dataframe with original df type information
    df_summary = pd.DataFrame({
        'Column': df.columns,
        'Data Type': df.dtypes,
        'Values Count': df.notnull().sum(),
        'Null Values': df.isnull().sum(),
        'Unique Values': df.nunique()
    })

    return df_summary

# %%
first_id = recipes_raw['RecipeId'].iloc[0]
print(f"La primera RecipeId es: {first_id}")
# Out:
# La primera RecipeId es: 38.0

# %%
recipes_raw.columns
# Out:
# Index(['RecipeId', 'Name', 'AuthorId', 'AuthorName', 'CookTime', 'PrepTime',
#        'TotalTime', 'DatePublished', 'Description', 'Images', 'RecipeCategory',
#        'Keywords', 'RecipeIngredientQuantities', 'RecipeIngredientParts',
#        'AggregatedRating', 'ReviewCount', 'RecipeServings', 'RecipeYield',
#        'RecipeInstructions', 'ingredients_cleaned', 'quantities_cleaned',
#        'TotalTimeMinutes'],
#       dtype='object')

# %%
recipes_raw.columns.tolist()
# Out:
# ['RecipeId',
#  'Name',
#  'AuthorId',
#  'AuthorName',
#  'CookTime',
#  'PrepTime',
#  'TotalTime',
#  'DatePublished',
#  'Description',
#  'Images',
#  'RecipeCategory',
#  'Keywords',
#  'RecipeIngredientQuantities',
#  'RecipeIngredientParts',
#  'AggregatedRating',
#  'ReviewCount',
#  'RecipeServings',
#  'RecipeYield',
#  'RecipeInstructions',
#  'ingredients_cleaned',
#  'quantities_cleaned',
#  'TotalTimeMinutes']

# %%
recipes_raw[['RecipeIngredientQuantities', 'RecipeIngredientParts']].head(10)
# Out:
#                           RecipeIngredientQuantities  \
# 0                                     [4, 1⁄4, 1, 1]
# 1  [1, 4, 2, 2, 8, 1⁄4, 8, 1⁄2, 1, 1, 1⁄4, 1⁄4, 1...
# 2                 [1 1⁄2, 1, None, 1 1⁄2, None, 3⁄4]
# 3  [12, 1, 2, 1, 10, 1, 3, 2, 2, 2, 1, 2, 1⁄2, 1⁄...
# 4                                   [46, 4, 1, 2, 1]
# 5  [1 1⁄4, 1⁄4, 6, 1⁄3, 1⁄4, 1⁄4, 2, 3, 1, 1, 1⁄4...
# 6  [12, 2, 3, 450, 1, 2, 1⁄4, 1, None, None, 2, 2...
# 7             [3⁄4, 1, 1, 2, 3, 1⁄4, 1, 1⁄2, 1⁄2, 2]
# 8                               [1⁄2, 5, 2, 1, 1, 1]
# 9                          [3⁄4, 1⁄2, 1, 1, 1, 2, 1]
#
#                                RecipeIngredientParts
# 0  [blueberries, granulated sugar, vanilla yogurt...
# 1  [saffron, milk, hot green chili peppers, onion...
# 2  [sugar, lemons, rind of, lemon, zest of, fresh...
# 3  [extra firm tofu, eggplant, zucchini, mushroom...
# 4  [plain tomato juice, cabbage, onion, carrots, ...
# 5  [graham cracker crumbs, sugar, butter, sugar, ...
# ...

# %%
recipes_cpath = "data/processed/recipes_embedded.parquet"
recipes = pd.read_parquet(recipes_cpath)

# %%
recipes.shape
# Out:
# (522517, 3)

# %%
r_sample.to_parquet("data/processed/recipes_sample.parquet")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 r_sample.to_parquet("data/processed/recipes_sample.parquet")
#
# NameError: name 'r_sample' is not defined

# %%
len(r_sample['ingredient_embeddings'].iloc[0])
# Out:
# 384

# %%
embedding_lengths = r_sample['ingredient_embeddings'].apply(len)

embedding_lengths.unique()
# Out:
# array([384])
